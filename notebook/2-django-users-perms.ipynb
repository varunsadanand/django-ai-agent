# %%
from django.contrib.auth import get_user_model
User = get_user_model()
User.objects.all()
# Out:
# <QuerySet [<User: varun>, <User: staff>, <User: Sonu>]>

# %%
import setup
setup.init(verbose=True)
# Out:
# Applied nest_asyncio patch
# Django initialized successfully

# %%
#user_obj=User.objects.create(
#    username="Sonu"
#)
user_obj=User.objects.get(
    username="Sonu"
)

#user_obj.is_staff=True

user_obj.set_password("abc123007")
user_obj.save()
user_obj.is_staff
#user_obj.save()
# Out:
# True

# %%
user_obj.password
# Out:
# 'pbkdf2_sha256$1200000$vIx1DpEUvB2CJc6yTF2207$ORH7uoXxAHVJxNK5BcbmzJGJNdr5Kpd2AmIrizyLhSs='

# %%
#help(User)

# %%
from docs.models import Document

doc_obj=Document(
    owner=user_obj,
    title="Hello World"
)
#create and update
#doc_obj.save()
doc_obj
# Out:
# <Document: <Hello World>

# %%
#delete
#doc_obj.delete()

# %%
user_obj=User.objects.last()
user_obj
# Out:
# <User: Sonu>

# %%
Document.objects.create(owner=user_obj)
# Out:
# <Document: <Title>

# %%
#superuser=admin user
#python manage.py createsuperuser
#

super_u=User.objects.filter(is_superuser=True).first()
super_u
# Out:
# <User: varun>

# %%
super_u.user_permissions.all()
# Out:
# <QuerySet []>

# %%
from django.contrib.auth.models import Permission
perms_u=Permission.objects.filter(codename__icontains="VIEW")

for i in perms_u:
    print(i.codename)
    staff_u.user_permissions.remove(i)
# Out:
# view_logentry
# view_group
# view_permission
# view_user
# view_contenttype
# view_document
# view_session

# %%
docs_u=Permission.objects.filter(codename__iendswith="document")
docs_u
#staff_u.user_permissions.set(perms_u)
# Out:
# <QuerySet [<Permission: Docs | document | Can add document>, <Permission: Docs | document | Can change document>, <Permission: Docs | document | Can delete document>, <Permission: Docs | document | Can view document>]>

# %%
new_perms= docs_u | perms_u
new_perms
# Out:
# <QuerySet [<Permission: Administration | log entry | Can view log entry>, <Permission: Authentication and Authorization | group | Can view group>, <Permission: Authentication and Authorization | permission | Can view permission>, <Permission: Authentication and Authorization | user | Can view user>, <Permission: Content Types | content type | Can view content type>, <Permission: Docs | document | Can add document>, <Permission: Docs | document | Can change document>, <Permission: Docs | document | Can delete document>, <Permission: Docs | document | Can view document>, <Permission: Sessions | session | Can view session>]>

# %%
staff_u.user_permissions.set(new_perms)

# %%
new_perms=new_perms.exclude(codename__icontains='delete')

# %%
staff_u=User.objects.filter(is_superuser=False,is_staff=True).first()
staff_u
# Out:
# <User: Sonu>

# %%
staff_u.user_permissions.all()
# Out:
# <QuerySet []>

# %%
user_obj.id
# Out:
# 2
